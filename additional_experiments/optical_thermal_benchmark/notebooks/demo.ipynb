# %% [markdown]
# # Optical–thermal restoration demo\nThis notebook runs the same deterministic experiment as `run_demo.py`. The included frames are synthetic so every step can be inspected; replace them with licensed iBVP frames for the real study.

# %%
from pathlib import Path\nimport runpy\nROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nrunpy.run_path(str(ROOT / 'run_demo.py'), run_name='__main__')

# %% [markdown]
# ## Read the metrics\nThe original clean image is only available during this controlled evaluation. In field deployment, validate downstream BVP/temperature accuracy against independent reference measurements.

# %%
import pandas as pd\npd.read_csv(ROOT / 'outputs' / 'metrics.csv').round(3)

# %%
from IPython.display import Image, display\nfor name in ['optical_comparison.png', 'thermal_comparison.png', 'waveform_comparison.png']:\n    display(Image(filename=str(ROOT / 'outputs' / name)))
